# %%
#Import libraries
import os
import csv
import hvplot
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as st
import seaborn as sns
from pprint import pprint 
from scipy.stats import linregress 

#Importing csv data
ev_stations_path = "Electric_and_Alternative_Fuel_Charging_Stations.csv"
ev_stations = pd.read_csv(ev_stations_path, low_memory=False)

ev_stations
# Out:
#       Fuel Type Code                                  Station Name  \
# 0                CNG          Spire - Montgomery Operations Center
# 1                CNG                           PS Energy - Atlanta
# 2                CNG  Metropolitan Atlanta Rapid Transit Authority
# 3                CNG                         United Parcel Service
# 4                CNG                    Arkansas Oklahoma Gas Corp
# ...              ...                                           ...
# 70401           ELEC                     SCHLITZ PARK SCHLITZ PARK
# 70402           ELEC                          NEXUS EAST STATION 2
# 70403           ELEC                                       Raley's
# 70404           ELEC                           13601 Glenoaks blvd
# 70405           ELEC                            6723 Van Nuys blvd
#
#                Street Address  \
# 0            2951 Chestnut St
# 1            340 Whitehall St
# 2         2424 Piedmont Rd NE
# 3        270 Marvin Miller Dr
# ...

# %%
ev_stations.columns
# Out:
# Index(['Fuel Type Code', 'Station Name', 'Street Address',
#        'Intersection Directions', 'City', 'State', 'ZIP', 'Plus4',
#        'Station Phone', 'Status Code', 'Expected Date',
#        'Groups With Access Code', 'Access Days Time', 'Cards Accepted',
#        'BD Blends', 'NG Fill Type Code', 'NG PSI', 'EV Level1 EVSE Num',
#        'EV Level2 EVSE Num', 'EV DC Fast Count', 'EV Other Info', 'EV Network',
#        'EV Network Web', 'Geocode Status', 'Latitude', 'Longitude',
#        'Date Last Confirmed', 'ID', 'Updated At', 'Owner Type Code',
#        'Federal Agency ID', 'Federal Agency Name', 'Open Date',
#        'Hydrogen Status Link', 'NG Vehicle Class', 'LPG Primary',
#        'E85 Blender Pump', 'EV Connector Types', 'Country',
#        'Intersection Directions (French)', 'Access Days Time (French)',
#        'BD Blends (French)', 'Groups With Access Code (French)',
#        'Hydrogen Is Retail', 'Access Code', 'Access Detail Code',
# ...

# %%
#Cleaning data
ev_stations_cleaned=ev_stations[['Fuel Type Code', 'Station Name', 'State', 'ZIP', 'Latitude', 'Longitude']]
ev_stations_cleaned
# Out:
#       Fuel Type Code                                  Station Name State  \
# 0                CNG          Spire - Montgomery Operations Center    AL
# 1                CNG                           PS Energy - Atlanta    GA
# 2                CNG  Metropolitan Atlanta Rapid Transit Authority    GA
# 3                CNG                         United Parcel Service    GA
# 4                CNG                    Arkansas Oklahoma Gas Corp    AR
# ...              ...                                           ...   ...
# 70401           ELEC                     SCHLITZ PARK SCHLITZ PARK    WI
# 70402           ELEC                          NEXUS EAST STATION 2    TX
# 70403           ELEC                                       Raley's    CA
# 70404           ELEC                           13601 Glenoaks blvd    CA
# 70405           ELEC                            6723 Van Nuys blvd    CA
#
#          ZIP   Latitude   Longitude
# 0      36107  32.367916  -86.267021
# ...

# %%
ev_stations_filtered=ev_stations_cleaned[ev_stations_cleaned['Fuel Type Code'] == 'ELEC']
ev_stations_filtered
# Out:
#       Fuel Type Code                     Station Name State    ZIP   Latitude  \
# 156             ELEC         LADWP - Truesdale Center    CA  91352  34.248319
# 157             ELEC  LADWP - West LA District Office    CA  90024  34.052542
# 158             ELEC    Los Angeles Convention Center    CA  90015  34.040539
# 159             ELEC    LADWP - John Ferraro Building    CA  90012  34.059133
# 160             ELEC       LADWP - Haynes Power Plant    CA  90803  33.759802
# ...              ...                              ...   ...    ...        ...
# 70401           ELEC        SCHLITZ PARK SCHLITZ PARK    WI  53212  43.050637
# 70402           ELEC             NEXUS EAST STATION 2    TX  78702  30.252438
# 70403           ELEC                          Raley's    CA  95650  38.817727
# 70404           ELEC              13601 Glenoaks blvd    CA  91342  34.318879
# 70405           ELEC               6723 Van Nuys blvd    CA  91405  34.192599
#
#         Longitude
# ...

# %%
ev_stations_filtered.to_csv("ev_stations_filtered.csv")

# %%
ev_stations_filtered.columns
# Out:
# Index(['Fuel Type Code', 'Station Name', 'State', 'ZIP', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
df = ev_stations_filtered

# %%
print(df['Fuel Type Code'].dtype)
# Out:
# object

# %%
import pandas as pd

# Read the CSV file into a DataFrame without header
df = pd.read_csv('ev_stations_filtered.csv', header=None)

# Drop the column you want to remove by positional index
column_index_to_remove = 0 # Replace 2 with the index of the column you want to remove
df.drop(columns=[column_index_to_remove], inplace=True)

# Save the DataFrame back to a CSV file
df.to_csv('ev_stations_filtered2.csv', index=False)  # Replace 'new_file.csv' with the desired filename

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('ev_stations_filtered2.csv')

# Check if ZIP codes are numeric
non_numeric_zips = df[~df['ZIP'].astype(str).str.isdigit()]

# Display any non-numeric ZIP codes
if not non_numeric_zips.empty:
    print("Non-numeric ZIP codes found:")
    print(non_numeric_zips)
else:
    print("All ZIP codes are numeric.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ZIP'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('ev_stations_filtered2.csv')

# Display the column names of the DataFrame
print(df.columns)
# Out:
# Index(['1', '2', '3', '4', '5', '6'], dtype='object')

# %%
import pandas as pd

# Read the CSV file into a DataFrame with specified column names
column_names = ['1', '2', '3', '4', '5', '6']  # Replace with actual column names
df = pd.read_csv('ev_stations_filtered2.csv', names=column_names)

# Rename the columns
new_column_names = ['Fuel Type Code', 'Station Name', 'State', 'ZIP', 'Latitude', 'Longitude']  # Replace with new column names
df.columns = new_column_names

# Display the first few rows of the DataFrame to verify the changes
print(df.head())

df.to_csv('ev_stations_filtered3.csv', index=False)  # Replace 'new_file_with_new_column_names.csv' with the desired filename
# Out:
#    Fuel Type Code                     Station Name  State    ZIP  \
# 0               1                                2      3      4
# 1  Fuel Type Code                     Station Name  State    ZIP
# 2            ELEC         LADWP - Truesdale Center     CA  91352
# 3            ELEC  LADWP - West LA District Office     CA  90024
# 4            ELEC    Los Angeles Convention Center     CA  90015
#
#            Latitude           Longitude
# 0                 5                   6
# 1          Latitude           Longitude
# 2  34.2483191527193  -118.3879713743439
# 3         34.052542         -118.448504
# 4         34.040539         -118.271387

# %%
index_to_remove = 1  # Replace with the index of the row you want to remove
df.drop(index=index_to_remove, inplace=True)

# %%
df
# Out:
#       Fuel Type Code                     Station Name State    ZIP  \
# 0                  1                                2     3      4
# 3               ELEC  LADWP - West LA District Office    CA  90024
# 4               ELEC    Los Angeles Convention Center    CA  90015
# 5               ELEC    LADWP - John Ferraro Building    CA  90012
# 6               ELEC       LADWP - Haynes Power Plant    CA  90803
# ...              ...                              ...   ...    ...
# 60904           ELEC        SCHLITZ PARK SCHLITZ PARK    WI  53212
# 60905           ELEC             NEXUS EAST STATION 2    TX  78702
# 60906           ELEC                          Raley's    CA  95650
# 60907           ELEC              13601 Glenoaks blvd    CA  91342
# 60908           ELEC               6723 Van Nuys blvd    CA  91405
#
#           Latitude     Longitude
# 0                5             6
# 3        34.052542   -118.448504
# 4        34.040539   -118.271387
# ...

# %%
index_to_remove = 0  # Replace with the index of the row you want to remove
df.drop(index=index_to_remove, inplace=True)

# %%
df
# Out:
#       Fuel Type Code                       Station Name State    ZIP  \
# 3               ELEC    LADWP - West LA District Office    CA  90024
# 4               ELEC      Los Angeles Convention Center    CA  90015
# 5               ELEC      LADWP - John Ferraro Building    CA  90012
# 6               ELEC         LADWP - Haynes Power Plant    CA  90803
# 7               ELEC  LADWP - Harbor Generating Station    CA  90744
# ...              ...                                ...   ...    ...
# 60904           ELEC          SCHLITZ PARK SCHLITZ PARK    WI  53212
# 60905           ELEC               NEXUS EAST STATION 2    TX  78702
# 60906           ELEC                            Raley's    CA  95650
# 60907           ELEC                13601 Glenoaks blvd    CA  91342
# 60908           ELEC                 6723 Van Nuys blvd    CA  91405
#
#           Latitude     Longitude
# 3        34.052542   -118.448504
# 4        34.040539   -118.271387
# 5        34.059133   -118.248589
# ...

# %%
# Save the DataFrame to a new CSV file with the changes made
df.to_csv('ev_stations_filtered4.csv', index=False)  # Replace 'new_file.csv' with the desired filename
